# %%
import tensorflow as tf
from tensorflow import keras

(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

#print(len(train_images), len(test_images))

#print(train_images[180])

train_images = train_images / 255.0
test_images = test_images / 255.0

model = keras.models.Sequential([keras.layers.Flatten(input_shape=(28, 28)),
                                 keras.layers.Dense(512, activation=tf.nn.relu),
                                 keras.layers.Dense(10, activation=tf.nn.softmax)])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

model.fit(train_images, train_labels, epochs=5)
classification = model.predict(test_images)
print(classification)

import matplotlib.pyplot as plt
plt.imshow(test_images[5])
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4735
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3604
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3215
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2968
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2788
# 313/313 [==============================] - 1s 2ms/step
# [[3.6594919e-08 1.7571816e-10 2.7906917e-09 ... 9.8025547e-03
#   1.3815361e-07 9.7923893e-01]
#  [2.0034678e-04 3.5382600e-11 9.9548900e-01 ... 5.7400211e-14
#   4.4871222e-09 4.4241406e-13]
#  [3.0041200e-08 9.9999982e-01 5.2531642e-11 ... 1.3852797e-20
#   1.2576549e-13 3.2434556e-15]
#  ...
#  [1.1540148e-03 3.8535877e-09 3.3233393e-04 ... 4.8862780e-10
#   9.9807024e-01 3.8805661e-10]
#  [1.3659307e-09 9.9998528e-01 1.6795267e-10 ... 2.3404848e-14
#   6.8297284e-10 2.1682767e-10]
#  [4.7518533e-05 1.3920125e-07 1.3362868e-04 ... 1.3435034e-02
#   8.6847722e-04 3.1596879e-04]]
