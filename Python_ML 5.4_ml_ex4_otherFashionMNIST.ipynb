# %%
#기계가 학습할 데이터 준비하기
import tensorflow as tf
from tensorflow import keras

(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

#print(len(train_images), len(test_images))

#데이터 정규화

train_images = train_images / 255.0
test_images = test_images / 255.0

#모델 구성하기

model = keras.models.Sequential([keras.layers.Flatten(input_shape=(28, 28)),
                                 keras.layers.Dense(512, activation=tf.nn.relu),
                                 keras.layers.Dense(10, activation=tf.nn.softmax)])

#컴파일

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

#학습하기 & 훈련된 모델을 통해 예측하기

model.fit(train_images, train_labels, epochs=5) #훈련용 데이터셋으로 5번 학습시킨다.
Classification = model.predict(test_images) #10,000개의 테스트용 데이터에 대해 예측하고, 그 결과를 변수 Classification에 담습니다. 
print(Classification[11]) #인덱스 11번 이미지에 대한 예측 결과를 확인합니다. 

import matplotlib.pyplot as plt
plt.imshow(test_images[11])  #matplotlib 라이브러리를 활용하여 실제 이미지도 함께 출력해보자
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4736
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3581
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3223
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3019
# Epoch 5/5
# ...
# 313/313 [==============================] - 1s 3ms/step
# [2.0249715e-06 1.2227761e-08 3.4192401e-06 8.3333504e-08 8.3831103e-05
#  9.9956697e-01 2.4746962e-05 1.4225813e-04 5.4355460e-05 1.2223823e-04]
