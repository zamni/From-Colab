# %%
import tensorflow as tf
from tensorflow import keras
(train_images, train_labels), (test_images, test_labels) = keras.datasets.mnist.load_data()

'''
print(len(train_images), len(train_labels))
print(len(test_images), len(test_labels))

print(type(train_images), type(train_labels))
print(type(test_images), type(test_labels))
'''
train_images = train_images / 255.0
test_images = test_images / 255.0

model = keras.models.Sequential([keras.layers.Flatten(input_shape=(28, 28)), #[1]
                                 keras.layers.Dense(512, activation=tf.nn.relu), #[2]
                                 keras.layers.Dense(10, activation=tf.nn.softmax)]) #[3]

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
model.fit(train_images, train_labels, epochs=5)
model.evaluate(test_images, test_labels)

classification = model.predict(test_images)
print(classification[100])

import matplotlib.pyplot as plt
plt.imshow(test_images[100])
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2023
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0812
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0542
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0380
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0287
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0753
# 313/313 [==============================] - 1s 4ms/step
# [1.2263380e-08 5.1202342e-10 4.1248489e-09 2.1863943e-10 1.2819100e-09
#  1.1302215e-07 9.9999982e-01 9.3190478e-09 3.8892150e-08 9.0806312e-12]
